# %%
pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from googleapiclient.discovery import build
import pandas as pd
import sys

# %%
# cwd = os.getcwd()
# print(f"Current working directory: {cwd}")
# Out:
# Current working directory: /Users/shilpapatel/shilpa/RMIT/SEM4/SoftwareEnggProject/Government-Digital-Transformation

# %%
utils_path = os.path.abspath(os.path.join(cwd, 'scripts', 'utils'))
sys.path.append(utils_path)
try:
    from youtube_config import YOUTUBE_API_KEY
    print(f"YouTube API Key: {YOUTUBE_API_KEY}")
except ModuleNotFoundError as e:
    print(e)
    print("Module not found. Please check the path and file name.")
# Out:
# YouTube API Key: AIzaSyDYXIKqxtbVClK07XXgCDCKkaEP981gark

# %%
api_key = YOUTUBE_API_KEY

# %%
#ABC_News australia
# channel_id = "UCVgO39Bk5sMo66-6o6Spn6Q"
#ATO
# channel_id = "UCnFDRHQwcJm0YtIVxHeWJPw"
#myGovID
# channel_id = "UCPtuqZ_Izgm_jsjRE_OX-ww"
#Australia Post 
# channel_id = "UCOQYY_DW3f0SuyGlOr0yWPA"
# tripleJ
# channel_id = "UCd2KNtfphz8HvYzM4pwtHmg"
#ABC ME
# channel_id = "UCgz70jJUTxGBmvaIi4duEAw"
# Air Force
# channel_id = "UC2ne2Dh50U9CBL4X3a-e-Gw"
#Australian Defence College
# channel_id = "UCol_mORmacfj3a2L041mmdQ"
#BOM Weather
channel_id ="UCNOlLwBZQLUPYUs31hVFeSA"

# %%
youtube = build('youtube','v3',developerKey = api_key)

# %% [markdown]
# # Function to get channel statistics

# %%
request = youtube.channels().list(part='snippet, contentDetails,statistics', id = "UCVgO39Bk5sMo66-6o6Spn6Q")
response = request.execute()

# %%
response = request.execute()
formatted_response = json.dumps(response, indent=4)
print("Formatted Response:", formatted_response)
# Out:
# Formatted Response: {
#     "kind": "youtube#channelListResponse",
#     "etag": "bm7YDFEpqYrY_R9lyWuT1h9lLT4",
#     "pageInfo": {
#         "totalResults": 1,
#         "resultsPerPage": 5
#     },
#     "items": [
#         {
#             "kind": "youtube#channel",
#             "etag": "4mFLMbqfEIaASOlwQdpKcSQesyI",
#             "id": "UCVgO39Bk5sMo66-6o6Spn6Q",
#             "snippet": {
#                 "title": "ABC News (Australia)",
# ...

# %%
def channelStats(youtube,channel_id):
    request = youtube.channels().list(part='snippet, contentDetails,statistics', id = channel_id)
    response = request.execute()
    channel_data = response['items'][0] if 'items' in response else None
    if channel_data:
        channel_info = {
            'channel_id': channel_data['id'],
            'title': channel_data['snippet']['title'],
            'viewCount': channel_data['statistics']['viewCount'],
            'subscriberCount': channel_data['statistics']['subscriberCount'],
            'videoCount': channel_data['statistics']['videoCount'],
            'uploadsPlaylistId': channel_data['contentDetails']['relatedPlaylists']['uploads']
        }
        return channel_info
    else:
        return None

# %%
channelStats = channelStats(youtube,channel_id)
channelStats
# Out:
# {'channel_id': 'UCNOlLwBZQLUPYUs31hVFeSA',
#  'title': 'Bureau of Meteorology',
#  'viewCount': '16155269',
#  'subscriberCount': '68800',
#  'videoCount': '1491',
#  'uploadsPlaylistId': 'UUNOlLwBZQLUPYUs31hVFeSA'}

# %%
playlist_id = channelStats['uploadsPlaylistId']
playlist_id
# Out:
# 'UUNOlLwBZQLUPYUs31hVFeSA'

# %% [markdown]
# # Function to get the videos ids for  all the uploaded videos

# %%
def getVideoIds(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )

    response = request.execute()

    video_ids = []

    # Extract video IDs from the initial response
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    # Continue fetching video IDs from subsequent pages, if any
    nextPageToken = response.get('nextPageToken')
    while nextPageToken:
        request = youtube.playlistItems().list(
            part='contentDetails',
            playlistId=playlist_id,
            maxResults=50,
            pageToken=nextPageToken
        )
        response = request.execute()

        # Extract video IDs from the current page
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        # Update nextPageToken for the next iteration
        nextPageToken = response.get('nextPageToken')

    return video_ids

# %%
video_ids = getVideoIds(youtube,playlist_id)
print(video_ids)
# print(len(video_ids))
# Out:
# ['QIWMaY9ZDz4', 'OOyNMGh4wfE', 'uxlzSoWDtE4', 'Ab5j70N5Z2A', 'GrSZUsi8Peg', '-u_p_-8cTFY', 'SyJoB7ufoFA', 'kFTbtRdBTyY', '4y6bYlCQnuk', '9IbEBA89GLU', '5lRits94Edo', 'nGa8OuaAHwk', 'Xy7A705WWSU', 'q1fkxItNS28', 'CTHNKtHOq_I', 'J2cHlA0J4S4', '_D9ys5mjILI', '1AaaK6UYsh4', 'lKZBAuD1itU', '3Ze_iwNwcr0', '9ciAc1SAb0Q', 'myv4CfjYQJg', 'GIOYmZ_u9UM', 'xzrkS5j07UA', 'eJCVIwpw0kw', 'WtqtBirHpbQ', 'cVp73t3brtA', '2JkMYAi_RYk', 'WVVXCanld-8', 'OcDmZ8MQ4rU', 'xrEoKNX73Pk', 'KPR0Z72Mw3o', '6egsjZNuezs', 'mVtSIyc_CP8', 'jLCuhF1dSHc', '1MP50uCb098', '7D5jUZCQs0w', 'ZRFc12ckWeM', 'AtHCcJHEg8o', 'lLeotqyfdX4', 'goBFmHSmlD8', 'DHoOmXabdpo', 'lgFYga6f0QU', '3cHEvj1DftY', 'CXYCeulsW6I', 'RTFGTCm46ys', 'gnmZQQLcUHE', 'O5wN7gtZLYg', '30NUM_FIMlg', '7b1X-H91V64', 'Cq2VBwcM2O0', 'FeUHNehaDFE', '70tWh9wF3bA', 'uKI60Uilm-8', 'eiCw-tYOPgs', 'aR6Lhj8iiEk', '4_pQt0uG-qA', '9e7E1ORvHdg', '0aX6T2dwvwA', 'omm2Wmp2cec', 'Ar2ojfPadaE', 'sPzUOm5Yhjw', 'Mba-nHDk_4k', 'HiFCyPb0jqE', 'g_c04oGIvZc', 'hYV_qqB8JFE', 'DglXQa
# ...

# %% [markdown]
# # Fuction to get each video statistics

# %%
def getvideoDetails(youtube, video_ids):
    allVideoStats = []
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            tags = ', '.join(video['snippet'].get('tags', []))
            videoStats = {
                'video_id': video['id'],
                'publishedAt': video['snippet']['publishedAt'],
                'channelId': video['snippet']['channelId'],
                'title': video['snippet']['title'],
                'viewCount': video['statistics']['viewCount'],
                'likeCount': video['statistics'].get('likeCount', 0),
                'favoriteCount': video['statistics'].get('favoriteCount', 0),
                'tags': tags
            }
            allVideoStats.append(videoStats)

    return allVideoStats

# %%
videoDetails = getvideoDetails(youtube,video_ids)
videoDetails
# Out:
# [{'video_id': 'QIWMaY9ZDz4',
#   'publishedAt': '2024-05-22T03:27:09Z',
#   'channelId': 'UCNOlLwBZQLUPYUs31hVFeSA',
#   'title': 'National Weather Update 22 May 2024: Frost in the east and cold fronts in the south.',
#   'viewCount': '3326',
#   'likeCount': '197',
#   'favoriteCount': '0',
#   'tags': 'Bureau of Meteorology, BOM, The Bureau, Australian Government, Australian Bureau Of Meteorology, Weather, Climate, Australian climate, Meteorology'},
#  {'video_id': 'OOyNMGh4wfE',
#   'publishedAt': '2024-05-20T04:23:44Z',
#   'channelId': 'UCNOlLwBZQLUPYUs31hVFeSA',
#   'title': 'Weather Update: National weather forecast, Monday 20 May 2024',
#   'viewCount': '3510',
#   'likeCount': '181',
#   'favoriteCount': '0',
#   'tags': 'Bureau of Meteorology, BOM, The Bureau, Australian Government, Australian Bureau Of Meteorology, Weather, Climate, Australian climate, Meteorology'},
#  {'video_id': 'uxlzSoWDtE4',
#   'publishedAt': '2024-05-19T04:00:30Z',
# ...

# %%
data = pd.DataFrame(videoDetails)

# %%
data
# Out:
#          video_id           publishedAt                 channelId  \
# 0     QIWMaY9ZDz4  2024-05-22T03:27:09Z  UCNOlLwBZQLUPYUs31hVFeSA
# 1     OOyNMGh4wfE  2024-05-20T04:23:44Z  UCNOlLwBZQLUPYUs31hVFeSA
# 2     uxlzSoWDtE4  2024-05-19T04:00:30Z  UCNOlLwBZQLUPYUs31hVFeSA
# 3     Ab5j70N5Z2A  2024-05-17T05:23:52Z  UCNOlLwBZQLUPYUs31hVFeSA
# 4     GrSZUsi8Peg  2024-05-17T04:01:23Z  UCNOlLwBZQLUPYUs31hVFeSA
# ...           ...                   ...                       ...
# 1487  OcndUrVzW20  2011-07-18T05:28:24Z  UCNOlLwBZQLUPYUs31hVFeSA
# 1488  TgyExadhxUw  2011-06-28T01:41:45Z  UCNOlLwBZQLUPYUs31hVFeSA
# 1489  qmDLawcz3y8  2011-06-28T01:04:46Z  UCNOlLwBZQLUPYUs31hVFeSA
# 1490  VrBu_P9OiAc  2011-06-28T00:50:55Z  UCNOlLwBZQLUPYUs31hVFeSA
# 1491  HnNtdJeBvhI  2011-06-28T00:23:38Z  UCNOlLwBZQLUPYUs31hVFeSA
#
#                                                   title viewCount likeCount  \
# 0     National Weather Update 22 May 2024: Frost in ...      3326       197
# ...

# %%
constant_values = {
    'channel_id': channelStats['channel_id'],
    'title': channelStats['title'],
    'total_viewCount': channelStats['viewCount'],
    'subscriberCount': channelStats['subscriberCount'],
    'videoCount': channelStats['videoCount']
}

num_rows = len(data)
constant_df = pd.DataFrame([constant_values] * num_rows)
data = pd.concat([constant_df, data], axis=1)
data.head()
# Out:
#                  channel_id                  title total_viewCount  \
# 0  UCNOlLwBZQLUPYUs31hVFeSA  Bureau of Meteorology        16155269
# 1  UCNOlLwBZQLUPYUs31hVFeSA  Bureau of Meteorology        16155269
# 2  UCNOlLwBZQLUPYUs31hVFeSA  Bureau of Meteorology        16155269
# 3  UCNOlLwBZQLUPYUs31hVFeSA  Bureau of Meteorology        16155269
# 4  UCNOlLwBZQLUPYUs31hVFeSA  Bureau of Meteorology        16155269
#
#   subscriberCount videoCount     video_id           publishedAt  \
# 0           68800       1491  QIWMaY9ZDz4  2024-05-22T03:27:09Z
# 1           68800       1491  OOyNMGh4wfE  2024-05-20T04:23:44Z
# 2           68800       1491  uxlzSoWDtE4  2024-05-19T04:00:30Z
# 3           68800       1491  Ab5j70N5Z2A  2024-05-17T05:23:52Z
# 4           68800       1491  GrSZUsi8Peg  2024-05-17T04:01:23Z
#
#                   channelId  \
# 0  UCNOlLwBZQLUPYUs31hVFeSA
# 1  UCNOlLwBZQLUPYUs31hVFeSA
# 2  UCNOlLwBZQLUPYUs31hVFeSA
# 3  UCNOlLwBZQLUPYUs31hVFeSA
# ...

# %% [markdown]
# # Store the data in a CSV file

# %%
datafile_dir = os.path.join('data', 'raw', 'youtube')
# Create the directory if it doesn't exist
if not os.path.exists(datafile_dir):
    os.makedirs(datafile_dir)

file_name = f"{channelStats['title'].replace(' ', '')}.csv"
full_file_path = os.path.join(datafile_dir, file_name)
data.to_csv(full_file_path, index=False)
print(f"DataFrame has been saved to '{full_file_path}'")
# Out:
# DataFrame has been saved to 'data/raw/youtube/BureauofMeteorology.csv'
