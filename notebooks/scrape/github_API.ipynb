# %%
import requests
import os
# https://docs.github.com/en/rest?apiVersion=2022-11-28
# get the current working directory
os.getcwd()
# Out:
# '/Users/tnathu-ai/VSCode/Government-Digital-Transformation/notebooks/scrape'

# %%
import sys
import os

# Add the directory containing config.py to the Python path
sys.path.append(os.path.abspath(os.path.join('..', '..')))

from config import EXCEL_KEYWORDS_LIST, GITHUB_RAW_DATA_DIR

# %% [markdown]
# # Refractor code

# %%
import os
import requests
import pandas as pd
import time

def fetch_and_save_github_repos(search_keywords, save_directory):
    query = ' OR '.join(search_keywords) + ' location:Australia'
    params = {
        'q': query,
        'sort': 'stars',  # Sort by stars to get popular repositories first
        'order': 'desc',
    }
    headers = {
        'Accept': 'application/vnd.github.v3+json',
    }

    try:
        response = requests.get('https://api.github.com/search/repositories', headers=headers, params=params)
        print(f"Initial response status: {response.status_code}")  # Print the initial response status

        if response.status_code == 403:  # HTTP 403 for rate limit exceeded
            print("Rate limit exceeded. Waiting 60 seconds...")
            time.sleep(60)
            response = requests.get('https://api.github.com/search/repositories', headers=headers, params=params)
            print(f"Response status after waiting: {response.status_code}")  # Print the response status after waiting

        response.raise_for_status()  # This will raise an exception for HTTP errors
        data = response.json()
        repos = []

        for item in data['items']:
            print(f"Processing repository: {item['name']}")  # Print the name of the repository being processed
            repos.append({
                "Repository Name": item['name'],
                "Description": item.get('description'),
                "Tags": ', '.join(item.get('topics', [])),
                "URL": item['html_url'],
                "Stars": item['stargazers_count'],
                "Forks": item['forks_count'],
                "Open Issues": item['open_issues_count'],
                "Language": item.get('language', 'Not specified'),
                "Date Published": item['created_at'],
                "Last Updated": item['updated_at'],
                "Latest Release": item.get('latest_release', 'Not specified')
            })

        if repos:
            df = pd.DataFrame(repos)
            file_name = f"{query.replace(' ', '_').replace(':', '_').replace('|', '_')}_{params['sort']}_github_repos.csv"
            # Ensure the directory exists
            os.makedirs(save_directory, exist_ok=True)
            save_path = os.path.join(save_directory, file_name)
            df.to_csv(save_path, index=False)
            print(f"Exported to {save_path}")
        else:
            print("No repositories found.")

    except requests.RequestException as e:
        print(f"Request failed: {e}")
    except requests.HTTPError as e:
        print(f"HTTP error occurred: {e}")  # HTTP error occurred
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# %%
# %%time

keywords = ['Australian government apps', 'Government Azure', 'COVID', 'crime', 'bushfire']
fetch_and_save_github_repos(keywords, GITHUB_RAW_DATA_DIR)
# Out:
# Initial response status: 200
# Processing repository: Horizon-dashboard
# Processing repository: AustralianRainfallPrediction
# Processing repository: Road-Accident-Analysis
# Processing repository: Ruritania
# Processing repository: -Taxi-Market-
# Exported to ../../data/raw/github/Australian_government_apps_OR_Government_Azure_OR_COVID_OR_crime_OR_bushfire_location_Australia_stars_github_repos.csv
# CPU times: user 55.5 ms, sys: 4.03 ms, total: 59.6 ms
# Wall time: 124 ms

# %% [markdown]
# # Scrape in batch
#
# + **Load Keywords from Excel:** The script starts by defining a function load_keywords that reads the 'Keywords' column from the specified Excel file path and returns these keywords as a list.
# + **Fetch and Save GitHub Repositories:** The fetch_and_save_github_repos function is updated to loop through each keyword. For each keyword, it builds a search query specifically for repositories in Australia.
# + **Error Handling:** It handles rate limiting by waiting 60 seconds when a 403 status code is received and continues with retries.
# + **Save Data:** For each keyword, the fetched data is saved as a CSV file in a specified directory.

# %%
import os
import requests
import pandas as pd
import time

# Load keywords from Excel file
def load_keywords(file_path):
    df = pd.read_excel(file_path)
    return df['Keywords'].tolist()

def fetch_and_save_github_repos(search_keywords, save_directory):
    for keyword in search_keywords:
        query = keyword + ' location:Australia'
        params = {
            'q': query,
            'sort': 'stars',  # Sort by stars to get popular repositories first
            'order': 'desc',
        }
        headers = {
            'Accept': 'application/vnd.github.v3+json',
        }

        try:
            response = requests.get('https://api.github.com/search/repositories', headers=headers, params=params)
            if response.status_code == 403:  # HTTP 403 for rate limit exceeded
                print("Rate limit exceeded. Waiting 60 seconds...")
                time.sleep(60)
                response = requests.get('https://api.github.com/search/repositories', headers=headers, params=params)

            response.raise_for_status()  # This will raise an exception for HTTP errors
            data = response.json()
            repos = []

            for item in data['items']:
                repos.append({
                    "Repository Name": item['name'],
                    "Description": item.get('description'),
                    "Tags": ', '.join(item.get('topics', [])),
                    "URL": item['html_url'],
                    "Stars": item['stargazers_count'],
                    "Forks": item['forks_count'],
                    "Open Issues": item['open_issues_count'],
                    "Language": item.get('language', 'Not specified'),
                    "Date Published": item['created_at'],
                    "Last Updated": item['updated_at'],
                    "Latest Release": item.get('latest_release', 'Not specified')
                })

            if repos:
                df = pd.DataFrame(repos)
                file_name = f"{keyword.replace(' ', '_').replace(':', '_').replace('|', '_')}_{params['sort']}_github_repos.csv"
                os.makedirs(save_directory, exist_ok=True)
                save_path = os.path.join(save_directory, file_name)
                df.to_csv(save_path, index=False)
                print(f"Exported {len(repos)} repositories to {save_path}")
            else:
                print(f"No repositories found for keyword: {keyword}")

        except requests.RequestException as e:
            print(f"Request failed for keyword: {keyword}, {e}")
        except requests.HTTPError as e:
            print(f"HTTP error occurred for keyword: {keyword}, {e}")  # HTTP error occurred
        except Exception as e:
            print(f"An unexpected error occurred for keyword: {keyword}, {e}")

# %%
# %%time
# Path to the Excel file with keywords
excel_path = EXCEL_KEYWORDS_LIST
keywords = load_keywords(excel_path)
fetch_and_save_github_repos(keywords, GITHUB_RAW_DATA_DIR)
# Out:
# No repositories found for keyword: Australia Digital Transformation
# No repositories found for keyword: Australia Digital Transformation
# Exported 5 repositories to ../../data/raw/github/Australia_Government__stars_github_repos.csv
# No repositories found for keyword: Australia Digital Identity
# No repositories found for keyword: Parliament of Australia
# No repositories found for keyword: Centrelink
# No repositories found for keyword: Australian Medicare
# No repositories found for keyword: Service New South Wales
# No repositories found for keyword: MyGov Australia
# No repositories found for keyword: JobSeeker Australia
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: NDIS Australia
# Exported 1 repositories to ../../data/raw/github/Home_Affairs_Australia_stars_github_repos.csv
# No repositories found for keyword: Smart Cities Australia
# Exported 1 repositories to ../../data/raw/github/Department_of_Health__Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Federal Police
# No repositories found for keyword: Bureau of Meteorology Australlia
# No repositories found for keyword: Australian Electoral Commission
# Exported 2 repositories to ../../data/raw/github/Public_Transport_Victoria_stars_github_repos.csv
# No repositories found for keyword: Australian Defence Force
# No repositories found for keyword: Australian Taxation Office
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Department of Education Australia
# Exported 1 repositories to ../../data/raw/github/Australian_Bureau_of_Statistics_stars_github_repos.csv
# No repositories found for keyword: CSIRO
# No repositories found for keyword: Department of Veterans' Affairs Australia
# Exported 2 repositories to ../../data/raw/github/Crime_Australia_stars_github_repos.csv
# No repositories found for keyword: Australia Foreign Affairs and Trade
# Exported 2 repositories to ../../data/raw/github/Australian_Immigration_stars_github_repos.csv
# No repositories found for keyword: JobKeeper Australia
# No repositories found for keyword: Australlia Government API
# Exported 1 repositories to ../../data/raw/github/GovHack_Australia_stars_github_repos.csv
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Cyber Security
# No repositories found for keyword: Data Archive Australia
# No repositories found for keyword: Australian Government Grants
# No repositories found for keyword: Australia National Health Services Directory
# No repositories found for keyword: Crime Statistics Australia
# Exported 1 repositories to ../../data/raw/github/e-Health_Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Environment Protection
# Exported 2 repositories to ../../data/raw/github/Australian_Business_Register_stars_github_repos.csv
# No repositories found for keyword: Australian Legal Information
# Exported 3 repositories to ../../data/raw/github/Australian_Government_Data_stars_github_repos.csv
# Rate limit exceeded. Waiting 60 seconds...
# Exported 1 repositories to ../../data/raw/github/National_Map_Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Public Service Jobs
# Exported 3 repositories to ../../data/raw/github/Australian_Renewable_Energy_stars_github_repos.csv
# No repositories found for keyword: Australia My Health Record
# No repositories found for keyword: Australian Student Loans
# No repositories found for keyword: Australian Pensions
# No repositories found for keyword: Australian Voting System
# Exported 3 repositories to ../../data/raw/github/Australia_post_api__stars_github_repos.csv
# No repositories found for keyword: Census Australia
# Exported 1 repositories to ../../data/raw/github/Australian_Government_Policies_stars_github_repos.csv
# Rate limit exceeded. Waiting 60 seconds...
# Exported 2 repositories to ../../data/raw/github/Australian_Border_Control_stars_github_repos.csv
# No repositories found for keyword: Emergency Management Australia
# No repositories found for keyword: Australian Government Health Alerts
# No repositories found for keyword: Australian National Audit Office
# Exported 11 repositories to ../../data/raw/github/Australia_Post_stars_github_repos.csv
# No repositories found for keyword: Australian Sports Commission
# No repositories found for keyword: Australian Agricultural Policies
# No repositories found for keyword: Australian Water Resources
# No repositories found for keyword: Australian National Parks
# No repositories found for keyword: National Disability Insurance Agency Australia
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Indigenous Affairs Australia
# No repositories found for keyword: Australian Fisheries Management
# No repositories found for keyword: Australian Federal Budget
# No repositories found for keyword: Australian Senate Enquiries
# No repositories found for keyword: Parliamentary Library Australia
# No repositories found for keyword: Australian Public Sector Innovation
# No repositories found for keyword: GovCMS
# No repositories found for keyword: Australian Energy Market Operator
# No repositories found for keyword: Aged Care Quality and Safety Commission
# No repositories found for keyword: Australian Maritime Safety Authority
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Customs Services
# Exported 4 repositories to ../../data/raw/github/Australian_Federal_Grants_stars_github_repos.csv
# No repositories found for keyword: National Library of Australia
# Exported 1 repositories to ../../data/raw/github/Australian_Road_Safety_stars_github_repos.csv
# No repositories found for keyword: Australian Rail Safety
# No repositories found for keyword: Australian Cultural Policy
# No repositories found for keyword: AUS POST
# Exported 1 repositories to ../../data/raw/github/Australian_Bushfire_stars_github_repos.csv
# Exported 3 repositories to ../../data/raw/github/Services_Victoria__stars_github_repos.csv
# No repositories found for keyword: Telehealth Services Australia
# Rate limit exceeded. Waiting 60 seconds...
# Exported 4 repositories to ../../data/raw/github/Australia_Covid_19_stars_github_repos.csv
# No repositories found for keyword: Australian Government Travel Advice
# Exported 1 repositories to ../../data/raw/github/Australian_National_Security_stars_github_repos.csv
# No repositories found for keyword: Australian Conservation Programs
# No repositories found for keyword: Australian Government Procurement
# No repositories found for keyword: Australia's Foreign Aid
# No repositories found for keyword: Australian Human Rights Commission
# No repositories found for keyword: Australian Workforce Statistics
# Exported 1 repositories to ../../data/raw/github/Australian_Government_Innovation_stars_github_repos.csv
# No repositories found for keyword: Australian Rural Development
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Urban Development
# No repositories found for keyword: Australian Indigenous Health
# No repositories found for keyword: Australian Biodiversity
# No repositories found for keyword: Australian Climate Change Policy
# No repositories found for keyword: Australia's Cyber Security Strategy
# No repositories found for keyword: Australian Government Blockchain Projects
# No repositories found for keyword: Australian Government Fintech Initiatives
# No repositories found for keyword: Australian Government Cybersecurity Grants
# Exported 1 repositories to ../../data/raw/github/Australian_Government_Cloud_Services_stars_github_repos.csv
# Exported 1 repositories to ../../data/raw/github/Australian_Government_Open_Source_Projects_stars_github_repos.csv
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Government Digital Identity
# No repositories found for keyword: National Broadband Network (NBN)
# No repositories found for keyword: Australian Public Sector Hackathons
# No repositories found for keyword: Australian Government Social Media Guidelines
# No repositories found for keyword: Australian Electoral Roll
# No repositories found for keyword: Australian Government Legal Database
# No repositories found for keyword: Australian Infrastructure Projects
# No repositories found for keyword: Commonwealth Ombudsman
# Exported 1 repositories to ../../data/raw/github/Australian_Human_Services_stars_github_repos.csv
# No repositories found for keyword: Indigenous Land Management
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Wildlife Services
# Exported 1 repositories to ../../data/raw/github/Clean_Energy_Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Quarantine Services
# No repositories found for keyword: Australian Export Controls
# No repositories found for keyword: Australian Financial Regulation
# No repositories found for keyword: Australian Pharmaceutical Benefits Scheme
# No repositories found for keyword: Australian Disability Policy
# No repositories found for keyword: Australian Mental Health Services
# No repositories found for keyword: Family Assistance Australia
# No repositories found for keyword: Australian Child Support Agency
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Superannuation
# No repositories found for keyword: Australian Aged Care
# No repositories found for keyword: Australian Housing Assistance
# Exported 2 repositories to ../../data/raw/github/Australian_Local_Government_stars_github_repos.csv
# No repositories found for keyword: Australian State Government Services
# Exported 5 repositories to ../../data/raw/github/Grant_Connect_Australia_stars_github_repos.csv
# No repositories found for keyword: Australia Attorney General Department
# No repositories found for keyword: Australia’s Anti-Discrimination
# No repositories found for keyword: Australian Tax Law
# No repositories found for keyword: Australian Energy Policy
# Rate limit exceeded. Waiting 60 seconds...
# Exported 2 repositories to ../../data/raw/github/Australian_Data_Protection_stars_github_repos.csv
# Exported 1 repositories to ../../data/raw/github/Australian_Water_Management_stars_github_repos.csv
# No repositories found for keyword: Australia Carbon Emissions
# No repositories found for keyword: Australian Space Agency
# No repositories found for keyword: Renewable Energy Targets Australia
# No repositories found for keyword: Australian Regional Development
# No repositories found for keyword: Australian Indigenous Programs
# No repositories found for keyword: National Health Reform Australia
# No repositories found for keyword: Australian Pharmaceutical Policy
# No repositories found for keyword: Australian Biotech Policy
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: National Crime Authority Australia
# No repositories found for keyword: Australian Internet Governance
# Exported 1 repositories to ../../data/raw/github/Australian_Technology_Innovation_stars_github_repos.csv
# No repositories found for keyword: Australian Science Research
# No repositories found for keyword: Australian Cultural Heritage
# No repositories found for keyword: Australian Smart Grid
# No repositories found for keyword: National Security Strategy Australia
# No repositories found for keyword: Australian Naval Development
# No repositories found for keyword: Australian Aviation Security
# No repositories found for keyword: Australian Telecommunication Policy
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Railway Expansion
# No repositories found for keyword: Australian Roads and Infrastructure
# No repositories found for keyword: Australian Immigration Reform
# No repositories found for keyword: Skilled Migration Australia
# Exported 3 repositories to ../../data/raw/github/Student_Visas_Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Refugee Policy
# Exported 1 repositories to ../../data/raw/github/Australian_Visa_Application_Process_stars_github_repos.csv
# No repositories found for keyword: Australian Citizenship Test
# No repositories found for keyword: Australian Diplomatic Missions
# Exported 1 repositories to ../../data/raw/github/Australia_in_the_Asia-Pacific_stars_github_repos.csv
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australia Global Trade Agreements
# No repositories found for keyword: Australian International Aid
# Exported 1 repositories to ../../data/raw/github/Australia_and_the_United_Nations_stars_github_repos.csv
# No repositories found for keyword: Australian Defence Force Modernization
# No repositories found for keyword: Veterans Affairs Australia
# No repositories found for keyword: Australian War Memorial
# No repositories found for keyword: Australian Reserve Bank
# No repositories found for keyword: Australian Economic Policy
# No repositories found for keyword: Australian Inflation Targets
# No repositories found for keyword: Australian Stock Exchange
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Corporate Governance
# No repositories found for keyword: National Anti-Corruption Commission
# No repositories found for keyword: Australian Consumer Rights
# No repositories found for keyword: Australian Product Safety
# No repositories found for keyword: Australian Import Restrictions
# No repositories found for keyword: Australian Export Markets
# No repositories found for keyword: Australian Biosecurity Measures
# No repositories found for keyword: National Environmental Policy Australia
# No repositories found for keyword: Australian Wildfire Management
# No repositories found for keyword: Australian Drought Response
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Flood Relief Efforts
# No repositories found for keyword: Australian Disaster Recovery
# No repositories found for keyword: Climate Adaptation Strategies Australia
# No repositories found for keyword: Australia Green Technology
# No repositories found for keyword: Australian Sustainable Cities
# No repositories found for keyword: Australian Urban Planning
# No repositories found for keyword: Australian Public Transportation Systems
# No repositories found for keyword: Smart Mobility Australia
# Exported 1 repositories to ../../data/raw/github/Australian_E-Government_Strategies_stars_github_repos.csv
# No repositories found for keyword: Digital Economy Australia
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Innovation in Australian SMEs
# No repositories found for keyword: Australian Start-up Ecosystem
# Exported 1 repositories to ../../data/raw/github/Australian_Intellectual_Property_stars_github_repos.csv
# No repositories found for keyword: Australian Patent Office
# Exported 2 repositories to ../../data/raw/github/Copyright_Law_Australia_stars_github_repos.csv
# No repositories found for keyword: Australian Trademark Law
# No repositories found for keyword: Internet Censorship Australia
# No repositories found for keyword: Australian Media Regulations
# No repositories found for keyword: Australian Broadcasting Corporation
# No repositories found for keyword: Special Broadcasting Service (SBS)
# Rate limit exceeded. Waiting 60 seconds...
# No repositories found for keyword: Australian Public Broadcasting
# No repositories found for keyword: Australian Cultural Funding
# No repositories found for keyword: Australian Art and Culture
# No repositories found for keyword: Australian Music Fund
# No repositories found for keyword: Australian Film Industry
# No repositories found for keyword: Australian Literary Grants
# CPU times: user 14.3 s, sys: 467 ms, total: 14.7 s
# Wall time: 21min 57s
